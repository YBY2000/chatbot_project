# %% [markdown]
# # The Peter Lynch Approach

# %% [markdown]
# **UI Suggestions:**
# - Build a UI that includes three key components (1) a chat-bot responds to user's questions with Peter Lynch investment insights (2) a dashboard to display the key financial ratios of all selected stocks, see DataFrame fin_data_df. (3) print the stock long-short receommendation list made by the K-Mean Cluster.
# - Set the Dow Jones stock portfolio to be the default selection, then allow users to add their own the stocks or remove some stocks from the default list.
# - Use my k-mean clustering algorithm below as the starting point, display the value-quality clustering figure and report the list of stocks to be long and the list of stocks to be short.
# - Ideally, you could include some high-level introduction and interpretation of the financial ratios reported in DataFrame fin_data_df into the question-answer pairs for your Chat-Bot.

# %% [markdown]
# #### reference:
# - https://home.csulb.edu/~pammerma/fin382/screener/lynch.htm

# %%
import pandas as pd
from yahooquery import Ticker

from numpy import where
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import make_classification
from matplotlib import pyplot
from numpy import unique
from sklearn.cluster import KMeans

import yahoo_fin.stock_info as si
import warnings
warnings.filterwarnings("ignore", category=Warning)

import random
random.seed(42)  # Set seed

# %%
# 1. list all stocks enlisted in Dow Jone Index
stock_symbol_list = si.tickers_dow()
print(f"All {len(stock_symbol_list)} Stocks in Dow Jones: {stock_symbol_list}.")
# Out:
# All 30 Stocks in Dow Jones: ['AAPL', 'AMGN', 'AMZN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'GS', 'HD', 'HON', 'IBM', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'NVDA', 'PG', 'SHW', 'TRV', 'UNH', 'V', 'VZ', 'WMT'].

# %%
# 2. list important financial ratios for all stocks in the list
ticker = Ticker(stock_symbol_list) 
fin_data_dict = ticker.financial_data
fin_data_df = pd.DataFrame.from_dict(fin_data_dict, orient='index').T
print(fin_data_df)

# preprocess debt-to-equity ratio to equity-to-debt ratio
fin_data_df.loc['debtToEquity'] = 1 / fin_data_df.loc['debtToEquity']
# Out:
#                                    AAPL           AMGN            AMZN  \
# maxAge                            86400          86400           86400
# currentPrice                     194.27         282.64          174.33
# targetHighPrice                   300.0          400.0           306.0
# targetLowPrice                    165.0          185.0           200.0
# targetMeanPrice                237.3895       317.1228       252.00317
# targetMedianPrice                 245.0          324.0           254.0
# recommendationMean                  2.0        2.43333         1.38028
# recommendationKey                   buy            buy      strong_buy
# numberOfAnalystOpinions              40             25              66
# totalCash                   53774999552    11973000192    101202001920
# totalCashPerShare                  3.58         22.288           9.549
# ebitda                   137352003584.0  15157000192.0  120467996672.0
# totalDebt                   96798998528    60878999552    155400994816
# quickRatio                        0.783          0.843           0.837
# currentRatio                      0.923          1.257           1.064
# totalRevenue               395760009216    33423998976    637959012352
# debtToEquity                      145.0       1035.886          54.342
# revenuePerShare                  25.974         62.242          60.915
# returnOnAssets                  0.22519          0.064         0.07438
# returnOnEquity                   1.3652        0.67553          0.2429
# grossProfits               184102993920    22965999616    311670996992
# freeCashflow              93833871360.0  13725875200.0   44635873280.0
# operatingCashflow        108293996544.0  11489999872.0  115877003264.0
# earningsGrowth                    0.101         -0.187           0.846
# revenueGrowth                      0.04          0.109           0.105
# grossMargins                    0.46519        0.68711         0.48854
# ebitdaMargins                   0.34706        0.45348         0.18883
# operatingMargins                0.34459        0.51805         0.11291
# profitMargins                   0.24295        0.12237         0.09287
# financialCurrency                   USD            USD             USD
#
#                                    AXP             BA            CAT  \
# maxAge                           86400          86400          86400
# currentPrice                    252.92         156.47         290.14
# targetHighPrice                  371.0          250.0         427.41
# targetLowPrice                   230.0          111.0          243.0
# targetMeanPrice               294.6388       193.0427       365.2561
# targetMedianPrice                285.0          200.0          380.0
# recommendationMean             2.51724            2.0        2.51852
# recommendationKey                 hold            buy           hold
# numberOfAnalystOpinions             25             26             23
# totalCash                  41109999616    26261000192     6165000192
# totalCashPerShare               58.517         35.011         12.899
# ebitda                             NaN  -8183000064.0  15646000128.0
# totalDebt                  55482998784    55957999616    39011000320
# quickRatio                       1.344          0.386          0.805
# currentRatio                     1.351          1.319          1.416
# totalRevenue               60764000256    66517000192    64809000960
# debtToEquity                    183.33            NaN        200.118
# revenuePerShare                 85.343        102.824         133.16
# returnOnAssets                 0.03804       -0.04269        0.09675
# returnOnEquity                 0.34735            NaN        0.55327
# grossProfits               39382999040    -1735000064    21088000000
# freeCashflow                       NaN  -9692999680.0   5219874816.0
# operatingCashflow        14049999872.0 -12080000000.0  12035000320.0
# earningsGrowth                   0.157            NaN          0.096
# revenueGrowth                    0.106         -0.308          -0.05
# grossMargins                   0.64813       -0.02608        0.32539
# ebitdaMargins                      0.0       -0.12302        0.24142
# operatingMargins               0.17832       -0.23947        0.19186
# profitMargins                  0.16669       -0.17765        0.16652
# financialCurrency                  USD            USD            USD
#
#                                    CRM           CSCO            CVX  \
# maxAge                           86400          86400          86400
# currentPrice                    249.84          55.76         135.36
# targetHighPrice                  442.0           80.0          197.0
# targetLowPrice                   243.0           54.0          140.0
# targetMeanPrice               371.1359       69.14913         171.15
# targetMedianPrice                375.0           70.0          173.0
# recommendationMean                1.75        2.11538           2.04
# recommendationKey                  buy            buy            buy
# numberOfAnalystOpinions             44             23             23
# totalCash                  14032000000    17643999232     6784999936
# totalCashPerShare               14.601          4.435          3.854
# ebitda                   11143000064.0  14588999680.0  40080998400.0
# totalDebt                  12069999616    32422000640    29610999808
# quickRatio                       0.928          0.659          0.709
# currentRatio                     1.062          0.867          1.061
# totalRevenue               37895000064    54175997952   195567992832
# debtToEquity                    19.731          71.21         19.334
# revenuePerShare                 39.392         13.517        108.049
# returnOnAssets                 0.04726        0.06556        0.05616
# returnOnEquity                 0.10258        0.20019        0.11266
# grossProfits               29251999744    35285999616    77298999296
# freeCashflow             14207750144.0  13290500096.0  16345624576.0
# operatingCashflow        13091999744.0  13603000320.0  31491999744.0
# earningsGrowth                   0.195         -0.061          0.515
# revenueGrowth                    0.076          0.094          0.086
# grossMargins                   0.77192        0.65132        0.39525
# ebitdaMargins                  0.29405        0.26929        0.20495
# operatingMargins               0.21195        0.22321        0.11394
# profitMargins                  0.16353        0.16958        0.09031
# financialCurrency                  USD            USD            USD
#
#                                    DIS  ...            MSFT           NKE  \
# maxAge                           86400  ...           86400         86400
# currentPrice                     82.77  ...          371.61         53.55
# targetHighPrice                  147.0  ...           650.0         120.0
# targetLowPrice                    79.0  ...           415.0          40.0
# targetMeanPrice              123.46538  ...         497.182      77.64306
# targetMedianPrice               125.55  ...           490.0          75.0
# recommendationMean             1.76667  ...         1.40678        2.2439
# recommendationKey                  buy  ...      strong_buy           buy
# numberOfAnalystOpinions             26  ...              50            36
# totalCash                   5486000128  ...     71554998272   10392999936
# totalCashPerShare                3.035  ...           9.625         7.041
# ebitda                   18449000448.0  ...  142041006080.0  5782000128.0
# totalDebt                  45307998208  ...    102909001728   11914999808
# quickRatio                       0.553  ...           1.204         1.326
# currentRatio                     0.679  ...           1.351         2.193
# totalRevenue               92501999616  ...    261802000384   47817998336
# debtToEquity                    42.447  ...          33.998        85.065
# revenuePerShare                 50.825  ...          35.224        32.035
# returnOnAssets                 0.04251  ...         0.14649       0.08262
# returnOnEquity                 0.05905  ...         0.34291       0.31934
# grossProfits               33984999424  ...    181714993152   20956000256
# freeCashflow             10820124672.0  ...   51958124544.0  5077624832.0
# operatingCashflow        14990999552.0  ...  125582999552.0  5854000128.0
# earningsGrowth                   0.346  ...           0.102        -0.302
# revenueGrowth                    0.048  ...           0.123        -0.093
# grossMargins                    0.3674  ...         0.69409       0.43825
# ebitdaMargins                  0.19944  ...         0.54255       0.12092
# operatingMargins               0.16784  ...         0.45458       0.06993
# profitMargins                   0.0607  ...         0.35428       0.09427
# financialCurrency                  USD  ...             USD           USD
#
#                                   NVDA             PG           SHW  \
# maxAge                           86400          86400         86400
# currentPrice                    104.49         166.39        331.28
# targetHighPrice                  220.0          200.0         420.0
# targetLowPrice                   115.0          143.0         247.0
# targetMeanPrice              166.95796       176.6888     372.36652
# targetMedianPrice                170.0          182.0         395.0
# recommendationMean             1.36508            2.0       2.24138
# recommendationKey           strong_buy            buy           buy
# numberOfAnalystOpinions             54             25            23
# totalCash                  43209998336    10229999616     210400000
# totalCashPerShare                1.771          4.363         0.842
# ebitda                   83316998144.0  24096000000.0  4399000064.0
# totalDebt                  10270000128    34687000576   12102599680
# quickRatio                       3.672          0.487          0.39
# currentRatio                      4.44          0.759         0.793
# totalRevenue              130497003520    84346003456   23098499072
# debtToEquity                    12.946         67.428       298.741
# revenuePerShare                  5.314         35.775        92.026
# returnOnAssets                 0.57417        0.10884       0.10129
# returnOnEquity                 1.19177        0.31058       0.69046
# grossProfits               97858002944    43620999168   11195100160
# freeCashflow             44169748480.0  11446250496.0  1924662528.0
# operatingCashflow        64089001984.0  18968999936.0  3153200128.0
# earningsGrowth                   0.836          0.341         0.357
# revenueGrowth                    0.779          0.021         0.009
# grossMargins                   0.74989        0.51717       0.48467
# ebitdaMargins                  0.63846        0.28568       0.19045
# operatingMargins               0.61107        0.27182       0.12684
# profitMargins                  0.55848        0.18353       0.11609
# financialCurrency                  USD            USD           USD
#
#                                    TRV            UNH              V  \
# maxAge                           86400          86400          86400
# currentPrice                    252.48         585.04         331.33
# targetHighPrice                  310.0          703.0          410.0
# targetLowPrice                  215.21         518.76          289.0
# targetMeanPrice              270.37946       637.7164      374.78973
# targetMedianPrice                274.0          642.0          386.0
# recommendationMean               2.625         1.2963        1.71795
# recommendationKey                 hold     strong_buy            buy
# numberOfAnalystOpinions             19             25             37
# totalCash                   5464999936    29112999936    14334000128
# totalCashPerShare               24.104         31.827          7.339
# ebitda                    7287000064.0  34986000384.0  25575000064.0
# totalDebt                   8307999744    81792999424    20608999424
# quickRatio                       0.187          0.747          0.708
# currentRatio                     0.322          0.827          1.121
# totalRevenue               46422999040   400277995520    36801998848
# debtToEquity                    29.816         79.727         53.815
# revenuePerShare                 203.61        434.612         19.663
# returnOnAssets                  0.0317        0.07056        0.16712
# returnOnEquity                 0.18941        0.15128        0.51191
# grossProfits               12391000064    89399001088    35997999104
# freeCashflow             16468500480.0  11574124544.0  13893749760.0
# operatingCashflow         9073999872.0  24203999232.0  21731999744.0
# earningsGrowth                   0.284          0.026          0.078
# revenueGrowth                    0.099          0.068          0.101
# grossMargins                   0.26692        0.22334        0.97815
# ebitdaMargins                  0.15697         0.0874        0.69494
# operatingMargins               0.22418        0.07711        0.68665
# profitMargins                  0.10768        0.03599        0.54269
# financialCurrency                  USD            USD            USD
#
#                                     VZ            WMT
# maxAge                           86400          86400
# currentPrice                     43.61          91.19
# targetHighPrice                   55.0          120.0
# targetLowPrice                    42.0           63.0
# targetMeanPrice               47.90217      106.59366
# targetMedianPrice                 47.0          108.0
# recommendationMean             2.30769        1.54545
# recommendationKey                  buy            buy
# numberOfAnalystOpinions             23             41
# totalCash                   4193999872     9036999680
# totalCashPerShare                0.996          1.127
# ebitda                   48790999040.0  42221998080.0
# totalDebt                 171694997504    62113001472
# quickRatio                       0.468          0.197
# currentRatio                     0.626          0.823
# totalRevenue              134787997696   680984969216
# debtToEquity                   170.713          63.58
# revenuePerShare                 31.955         84.689
# returnOnAssets                 0.05049        0.07124
# returnOnEquity                 0.18469        0.21414
# grossProfits               80880001024   169232007168
# freeCashflow             16012250112.0   7864625152.0
# operatingCashflow        36912001024.0  36443000832.0
# earningsGrowth                     NaN         -0.023
# revenueGrowth                    0.016          0.041
# grossMargins                   0.60005        0.24851
# ebitdaMargins                  0.36198          0.062
# operatingMargins               0.21227        0.04132
# profitMargins                  0.12988        0.02854
# financialCurrency                  USD            USD
#
# [30 rows x 30 columns]

# %%
# Transposing the DataFrame
data_full = fin_data_df.T 
# Replacing NaN values with 0
data = data_full.fillna(0)

# prepare raw data for clustering
X = data.drop(['maxAge','currentPrice','targetHighPrice', 'targetLowPrice', 
               'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 
               'recommendationKey', 'numberOfAnalystOpinions','financialCurrency'], axis=1).to_numpy()

# Initializing MinMaxScaler
scaler = MinMaxScaler()
# Applying Min-Max Scaling
X = scaler.fit_transform(X)

# k-means clustering
# define the model
# Set random seed for reproducibility
model = KMeans(n_clusters=4, random_state=100)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
 # get row indexes for samples with this cluster
 row_ix = where(yhat == cluster)
 # create scatter of these samples
 pyplot.scatter(X[row_ix, 0], X[row_ix, 1])

# show the plot
pyplot.xlabel('Value')
pyplot.ylabel('Quality')
pyplot.show()

# print alerted entities
print('Long Stocks: \n', data.index[yhat == 3])
print('Short Stocks: \n', data.index[yhat == 2])
# Out:
# Long Stocks:
#  Index(['JPM'], dtype='object')
# Short Stocks:
#  Index(['AAPL', 'AMZN', 'MSFT', 'NVDA'], dtype='object')

# %%
data.head()
# Out:
#       maxAge  currentPrice  targetHighPrice  targetLowPrice  targetMeanPrice  \
# AAPL   86400        194.27            300.0           165.0        237.38950
# AMGN   86400        282.64            400.0           185.0        317.12280
# AMZN   86400        174.33            306.0           200.0        252.00317
# AXP    86400        252.92            371.0           230.0        294.63880
# BA     86400        156.47            250.0           111.0        193.04270
#
#       targetMedianPrice  recommendationMean recommendationKey  \
# AAPL              245.0             2.00000               buy
# AMGN              324.0             2.43333               buy
# AMZN              254.0             1.38028        strong_buy
# AXP               285.0             2.51724              hold
# BA                200.0             2.00000               buy
#
#       numberOfAnalystOpinions     totalCash  ...  grossProfits  freeCashflow  \
# AAPL                       40   53774999552  ...  184102993920  9.383387e+10
# AMGN                       25   11973000192  ...   22965999616  1.372588e+10
# AMZN                       66  101202001920  ...  311670996992  4.463587e+10
# AXP                        25   41109999616  ...   39382999040  0.000000e+00
# BA                         26   26261000192  ...   -1735000064 -9.693000e+09
#
#       operatingCashflow  earningsGrowth  revenueGrowth  grossMargins  \
# AAPL       1.082940e+11           0.101          0.040       0.46519
# AMGN       1.149000e+10          -0.187          0.109       0.68711
# AMZN       1.158770e+11           0.846          0.105       0.48854
# AXP        1.405000e+10           0.157          0.106       0.64813
# BA        -1.208000e+10           0.000         -0.308      -0.02608
#
#       ebitdaMargins  operatingMargins  profitMargins  financialCurrency
# AAPL        0.34706           0.34459        0.24295                USD
# AMGN        0.45348           0.51805        0.12237                USD
# AMZN        0.18883           0.11291        0.09287                USD
# AXP         0.00000           0.17832        0.16669                USD
# BA         -0.12302          -0.23947       -0.17765                USD
#
# [5 rows x 30 columns]
